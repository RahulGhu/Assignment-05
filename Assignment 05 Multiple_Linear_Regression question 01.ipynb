# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # loading data

# %%
Fifty_Startups = pd.read_csv(r"D:\Data Science Material\Assignments\Multi Linear Regression assignment\50_Startups.csv")

# %%
Fifty_Startups[0:5]  # 1st five cols
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
Fifty_Startups.tail(5)    # last five cols
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
Fifty_Startups.info() # all info about data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
Fifty_Startups.dtypes   # data types of all cols
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
Fifty_Startups.shape
# Out:
# (50, 5)

# %%
Fifty_Startups01.value_counts()  # showing repeat state
# Out:
# R_and_D_Spend  Administration  Marketing_Spend  Profit
# 0              116983          45173            14681     1
# 101913         110594          229160           146121    1
# 76253          113867          298664           118474    1
# 77044          99281           140574           108552    1
# 78013          121597          264346           126992    1
# 78389          153773          299737           111313    1
# 86419          153514          0                122776    1
# 91749          114175          294919           124266    1
# 91992          135495          252664           134307    1
# 93863          127320          249839           141585    1
# 94657          145077          282574           125370    1
# 100671         91790           249744           144259    1
# 114523         122616          261776           129917    1
# 0              135426          0                42559     1
# 119943         156547          256512           132602    1
# ...

# %%
Fifty_Startups01 = Fifty_Startups.copy()  # secure data for future

# %%
Fifty_Startups01.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
 #  renaming cols for bettr use 
Fifty_Startups01 = Fifty_Startups01.rename({'R&D Spend':'R_and_D_Spend','Marketing_Spend':'Marketing_Spend'},axis=1)

# %%
Fifty_Startups01.head()
# Out:
#    R_and_D_Spend  Administration  Marketing_Spend       State     Profit
# 0      165349.20       136897.80        471784.10    New York  192261.83
# 1      162597.70       151377.59        443898.53  California  191792.06
# 2      153441.51       101145.55        407934.54     Florida  191050.39
# 3      144372.41       118671.85        383199.62    New York  182901.99
# 4      142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# # Visualization

# %%
# histogram for profit 
plt.hist(Fifty_Startups01.Profit)
plt.show()

# %%
# histogram for Marketing_Spend 
plt.hist(Fifty_Startups01.Marketing_Spend)
plt.show()

# %%
# histogram for Administration
plt.hist(Fifty_Startups01.Administration)
plt.show()

# %%
# histogram for R_and_D_Spend
plt.hist(Fifty_Startups01.R_and_D_Spend)
plt.show()

# %%
# line chart betwn R_and_D_Spend n Profit

fig = plt.figure(figsize=(10,3))

plt.plot(Fifty_Startups01.R_and_D_Spend, Fifty_Startups01.Profit)
#plt.xlim(0, 5)
#plt.ylim(0, 5)
plt.xlabel('X Axis')
plt.ylabel('Y axis')
plt.title('Line Plot')
plt.show()

# %%
# striplot
sns.stripplot(y= 'Profit', data=Fifty_Startups01,jitter=True)
plt.show()

# %%
# scatterplot for data visualization
sns.scatterplot(x='R_and_D_Spend', y= 'Profit', data=Fifty_Startups01)
plt.show()

# %%
# scatterplot for data visualization
sns.scatterplot(x='Administration', y= 'Profit', data=Fifty_Startups01)
plt.show()

# %%
# scatterplot for data visualization
sns.scatterplot(x='Marketing_Spend', y= 'Profit', data=Fifty_Startups01)
plt.show()

# %%
# scatterplot for data visualization but not usefull for me 
sns.scatterplot(x='Profit', y= 'Profit', data=Fifty_Startups01)
plt.show()

# %%
#Joint plot , scatter and barplot

sns.jointplot(x= 'R_and_D_Spend', y= 'Profit', data=Fifty_Startups01)
plt.show()

# %%
#Pair plot
sns.pairplot(Fifty_Startups01, hue='State')
plt.show()

# %% [markdown]
# # Outlier Detection

# %%
# box plot
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.boxplot(Fifty_Startups01['R_and_D_Spend'])
plt.show()

plt.figure(figsize=(10,3))
plt.subplot(1,2,2)
sns.boxplot(Fifty_Startups01['Administration'])
plt.show()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# box plot
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.boxplot(Fifty_Startups01['Marketing_Spend'])
plt.show()

plt.figure(figsize=(10,3))
plt.subplot(1,2,2)
sns.boxplot(Fifty_Startups01['Profit'])
plt.show()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# histogram 
Fifty_Startups01['Profit'].hist()
plt.show()

# %%
# OLS stands for ordinary least squares. 
# OLS is heavily used in econometrics—a branch of economics where statistical methods 
# are used to find the insights in economic data
import statsmodels.formula.api as smf
model = smf.ols("Profit ~ R_and_D_Spend",data = Fifty_Startups01).fit()

# %%
model.summary()  # gives statical information
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     849.8
# Date:                Sat, 21 Aug 2021   Prob (F-statistic):           3.50e-32
# Time:                        23:35:54   Log-Likelihood:                -527.44
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      48   BIC:                             1063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
# qq plot , When the quantiles of two variables are plotted against each other, 
# then the plot obtained is known as quantile – quantile plot or qqplot. 
# This plot provides a summary of whether the distributions of two variables are similar or not with respect to the locations
import statsmodels.api as sm
qqplot = sm.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %% [markdown]
# # Residual Vs Regressors

# %%
# regression plot and rsidual plot 
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "R_and_D_Spend", fig=fig)
plt.show()

# %% [markdown]
# ## Data Wrangling / Cleanining

# %%
# heat map for null values 
sns.heatmap(Fifty_Startups01.isnull(),yticklabels=True,cmap='gray')
plt.show()

# %%
Fifty_Startups01.describe()
# Out:
#        R_and_D_Spend  Administration  Marketing_Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
outlier_profit = Fifty_Startups01.iloc[49:50,0:5]  # for just seeing outlier

# %%
outlier_profit
# Out:
#     R_and_D_Spend  Administration  Marketing_Spend       State   Profit
# 49            0.0        116983.8         45173.06  California  14681.4

# %%
# mean
Fifty_Startups01.mean()
# Out:
# <ipython-input-89-eb4071b8818a>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Fifty_Startups01.mean()
# R_and_D_Spend       73721.6156
# Administration     121344.6396
# Marketing_Spend    211025.0978
# Profit             112012.6392
# dtype: float64

# %%
# median
Fifty_Startups01.median()
# Out:
# <ipython-input-91-ae4d423de386>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Fifty_Startups01.median()
# R_and_D_Spend       73051.080
# Administration     122699.795
# Marketing_Spend    212716.240
# Profit             107978.190
# dtype: float64

# %%
# standard deviation
Fifty_Startups01.std()
# Out:
# <ipython-input-92-f3e5ff5b1c2c>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Fifty_Startups01.std()
# R_and_D_Spend       45902.256482
# Administration      28017.802755
# Marketing_Spend    122290.310726
# Profit              40306.180338
# dtype: float64

# %%
# variance
Fifty_Startups01.var()
# Out:
# <ipython-input-94-e023bcf4d214>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Fifty_Startups01.var()
# R_and_D_Spend      2.107017e+09
# Administration     7.849973e+08
# Marketing_Spend    1.495492e+10
# Profit             1.624588e+09
# dtype: float64

# %%
# kurtosis
Fifty_Startups01.kurtosis()
# Out:
# <ipython-input-96-3462b1873830>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Fifty_Startups01.kurtosis()
# R_and_D_Spend     -0.761465
# Administration     0.225071
# Marketing_Spend   -0.671701
# Profit            -0.063859
# dtype: float64

# %%
# perticuler cols in ascending order
print(Fifty_Startups01.sort_values(by=('R_and_D_Spend'),ascending=True).head())
# Out:
#     R_and_D_Spend  Administration  Marketing_Spend       State    Profit
# 49           0.00       116983.80         45173.06  California  14681.40
# 47           0.00       135426.92             0.00  California  42559.73
# 48         542.05        51743.15             0.00    New York  35673.41
# 45        1000.23       124153.04          1903.93    New York  64926.08
# 46        1315.46       115816.21        297114.46     Florida  49490.75

# %%
# perticuler cols in ascending order
print(Fifty_Startups01.sort_values(by=('Administration'),ascending=True).head())
# Out:
#     R_and_D_Spend  Administration  Marketing_Spend       State    Profit
# 37       44069.95        51283.14        197029.42  California  89949.14
# 48         542.05        51743.15             0.00    New York  35673.41
# 38       20229.59        65947.93        185265.10    New York  81229.06
# 39       38558.51        82982.09        174999.30  California  81005.76
# 41       27892.92        84710.77        164470.71     Florida  77798.83

# %%
# perticuler cols in ascending order
print(Fifty_Startups01.sort_values(by=('Marketing_Spend'),ascending=True).head(),'\n')
# Out:
#     R_and_D_Spend  Administration  Marketing_Spend       State     Profit
# 47           0.00       135426.92             0.00  California   42559.73
# 48         542.05        51743.15             0.00    New York   35673.41
# 19       86419.70       153514.11             0.00    New York  122776.86
# 45        1000.23       124153.04          1903.93    New York   64926.08
# 44       22177.74       154806.14         28334.72  California   65200.33

# %%
# perticuler cols in ascending order
print(Fifty_Startups01.sort_values(by=('Profit'),ascending=True).head(),'\n')
# Out:
#     R_and_D_Spend  Administration  Marketing_Spend       State    Profit
# 49           0.00       116983.80         45173.06  California  14681.40
# 48         542.05        51743.15             0.00    New York  35673.41
# 47           0.00       135426.92             0.00  California  42559.73
# 46        1315.46       115816.21        297114.46     Florida  49490.75
# 45        1000.23       124153.04          1903.93    New York  64926.08

# %%
# droping unwanted cols
Fifty_Startups01.drop(['State'],axis=1,inplace=True)

# %%
Fifty_Startups01.head()
# Out:
#    R_and_D_Spend  Administration  Marketing_Spend     Profit
# 0      165349.20       136897.80        471784.10  192261.83
# 1      162597.70       151377.59        443898.53  191792.06
# 2      153441.51       101145.55        407934.54  191050.39
# 3      144372.41       118671.85        383199.62  182901.99
# 4      142107.34        91391.77        366168.42  166187.94

# %%
# Standardize data (0 mean, 1 stdev)
from sklearn.preprocessing import StandardScaler

# %%
 Fifty_Startups01.values
# Out:
# array([[165349.2 , 136897.8 , 471784.1 , 192261.83],
#        [162597.7 , 151377.59, 443898.53, 191792.06],
#        [153441.51, 101145.55, 407934.54, 191050.39],
#        [144372.41, 118671.85, 383199.62, 182901.99],
#        [142107.34,  91391.77, 366168.42, 166187.94],
#        [131876.9 ,  99814.71, 362861.36, 156991.12],
#        [134615.46, 147198.87, 127716.82, 156122.51],
#        [130298.13, 145530.06, 323876.68, 155752.6 ],
#        [120542.52, 148718.95, 311613.29, 152211.77],
#        [123334.88, 108679.17, 304981.62, 149759.96],
#        [101913.08, 110594.11, 229160.95, 146121.95],
#        [100671.96,  91790.61, 249744.55, 144259.4 ],
#        [ 93863.75, 127320.38, 249839.44, 141585.52],
#        [ 91992.39, 135495.07, 252664.93, 134307.35],
#        [119943.24, 156547.42, 256512.92, 132602.65],
#        [114523.61, 122616.84, 261776.23, 129917.04],
#        [ 78013.11, 121597.55, 264346.06, 126992.93],
#        [ 94657.16, 145077.58, 282574.31, 125370.37],
# ...

# %%
# converting data type
Fifty_Startups01['R_and_D_Spend'] = (Fifty_Startups01['R_and_D_Spend'].astype(int))

# %%
# converting data type
Fifty_Startups01['Administration'] = (Fifty_Startups01['Administration'].astype(int))

# %%
# converting data type
Fifty_Startups01['Marketing_Spend'] = (Fifty_Startups01['Marketing_Spend'].astype(int))

# %%
# converting data type
Fifty_Startups01['Profit'] = (Fifty_Startups01['Profit'].astype(int))

# %%
Fifty_Startups01.head()
# Out:
#    R_and_D_Spend  Administration  Marketing_Spend  Profit
# 0         165349          136897           471784  192261
# 1         162597          151377           443898  191792
# 2         153441          101145           407934  191050
# 3         144372          118671           383199  182901
# 4         142107           91391           366168  166187

# %%
# showing null values
Fifty_Startups01.isna().sum()
# Out:
# R_and_D_Spend      0
# Administration     0
# Marketing_Spend    0
# Profit             0
# dtype: int64

# %%
# filling null values with mean
Fifty_Startups01.R_and_D_Spend.fillna(73721.6156,inplace=True)

# %%
# filling null values with mean
Fifty_Startups01.Administration.fillna(121344.6396,inplace=True)

# %%
 # filling null values with mean
Fifty_Startups01.Marketing_Spend.fillna(211025.0978,inplace=True)

# %%
# filling null values with mean
Fifty_Startups01.Profit.fillna(112012.6392,inplace=True)

# %%
Fifty_Startups01
# Out:
#     R_and_D_Spend  Administration  Marketing_Spend  Profit
# 0          165349          136897           471784  192261
# 1          162597          151377           443898  191792
# 2          153441          101145           407934  191050
# 3          144372          118671           383199  182901
# 4          142107           91391           366168  166187
# 5          131876           99814           362861  156991
# 6          134615          147198           127716  156122
# 7          130298          145530           323876  155752
# 8          120542          148718           311613  152211
# 9          123334          108679           304981  149759
# 10         101913          110594           229160  146121
# 11         100671           91790           249744  144259
# 12          93863          127320           249839  141585
# 13          91992          135495           252664  134307
# 14         119943          156547           256512  132602
# ...

# %%
# for null values showing
Fifty_Startups01.isna().sum()
# Out:
# R_and_D_Spend      0
# Administration     0
# Marketing_Spend    0
# Profit             0
# dtype: int64

# %%
# duplicated values in data showing
Fifty_Startups01.duplicated()  # no duplicated values in data
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
# cross validation betn 2 var
pd.crosstab(Fifty_Startups01.R_and_D_Spend[0:5],Fifty_Startups01.Profit[0:5])
# Out:
# Profit         166187  182901  191050  191792  192261
# R_and_D_Spend
# 142107              1       0       0       0       0
# 144372              0       1       0       0       0
# 153441              0       0       1       0       0
# 162597              0       0       0       1       0
# 165349              0       0       0       0       1

# %%
# fitting an tranforming data
array = Fifty_Startups01.values
scaler = StandardScaler().fit(array)
rescaledX = scaler.transform(array)

# summarize transformed data
np.set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[ 2.02  0.56  2.15  2.01]
#  [ 1.96  1.08  1.92  2.  ]
#  [ 1.75 -0.73  1.63  1.98]
#  [ 1.55 -0.1   1.42  1.78]
#  [ 1.5  -1.08  1.28  1.36]]

# %% [markdown]
# # Build Model

# %%
Fifty_Startups01.head()
# Out:
#    R_and_D_Spend  Administration  Marketing_Spend  Profit
# 0         165349          136897           471784  192261
# 1         162597          151377           443898  191792
# 2         153441          101145           407934  191050
# 3         144372          118671           383199  182901
# 4         142107           91391           366168  166187

# %%
# generate R-Squared and AIC values
final_ml_V= smf.ols('Profit~R_and_D_Spend+Marketing_Spend+Administration',data = Fifty_Startups01).fit()

# %%
(final_ml_V.rsquared,final_ml_V.aic)
# Out:
# (0.9507456395777282, 1058.7718036695933)

# %%
#Exclude variable "Administration" and generate R-Squared and AIC values
final_ml_W= smf.ols('Profit~R_and_D_Spend+Marketing_Spend',data = Fifty_Startups01).fit()

# %%
(final_ml_W.rsquared,final_ml_W.aic)
# Out:
# (0.9504499411896593, 1057.0710810432083)

# %% [markdown]
# # Cook’s Distance

# %%
model_influence_V = final_ml_V.get_influence()
(c_V, _) = model_influence_V.cooks_distance

# %%
fig= plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(Fifty_Startups01)),np.round(c_V,3));
plt.xlabel('Row index')
plt.ylabel('Cooks Distance');
plt.show()

# %% [markdown]
# ## Predicting model

# %%
final_ml_V.predict(Fifty_Startups01).head()
# Out:
# 0    192520.960308
# 1    189156.044016
# 2    182146.717946
# 3    173696.221203
# 4    172139.099123
# dtype: float64

# %%
final_ml_V.predict(Fifty_Startups01.iloc[0:5,])
# Out:
# 0    192520.960308
# 1    189156.044016
# 2    182146.717946
# 3    173696.221203
# 4    172139.099123
# dtype: float64

# %%
pred_y = final_ml_V.predict(Fifty_Startups01)

# %%
pred_y
# Out:
# 0     192520.960308
# 1     189156.044016
# 2     182146.717946
# 3     173696.221203
# 4     172139.099123
# 5     163579.922080
# 6     158113.480623
# 7     160021.072966
# 8     151741.135277
# 9     154883.805685
# 10    135508.767126
# 11    135572.793413
# 12    129137.298055
# 13    127487.504716
# 14    149548.254140
# 15    146234.517479
# 16    116915.204513
# 17    130192.181492
# 18    129013.976350
# 19    115634.413424
# 20    116638.863092
# 21    117318.954651
# 22    114706.436753
# 23    109996.074960
# 24    113362.781374
# 25    102236.977902
# 26    110599.721592
# 27    114407.493045
# 28    101659.432800
# 29    101794.409105
# 30     99451.817151
# 31     97687.387707
# 32     99000.453429
# 33     97914.120079
# 34     89039.103340
# 35     90511.476807
# 36     75285.450134
# 37     89618.672315
# 38     69696.903182
# 39     83728.491876
# 40     74815.567638
# 41     74801.720345
# 42     70619.575781
# 43     60166.312985
# 44     64610.582622
# ...
